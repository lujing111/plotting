# %%
import numpy as np
import scipy.io
import matplotlib.pyplot as plt
import pandas as pd
from  pandas import DataFrame
from pandas import Series, ExcelWriter
import seaborn as sns

# %%
cd "C:\Users\Administrator\Desktop\data analysis\EEG\MAE and cognition"
# Out:
# C:\Users\Administrator\Desktop\data analysis\EEG\MAE and cognition

# %%
data = pd.read_excel('random_forest_adult(100)_children(112)predict age and MAE and cognition.xlsx', 'children_adult')
data.head(5)
# Out:
#                    subjects  sex  age   pred_age  MAE_random_forest  blocks  \
# 0  '105020102-restingopen1'    1    7   9.606771           2.606771      11
# 1  '105020105-restingopen1'    2    7   8.778341           1.778341      11
# 2  '105020106-restingopen1'    1    7   9.652398           2.652398      11
# 3  '105020108-restingopen1'    2    7  11.078537           4.078537      10
# 4  '105020109-restingopen1'    2    7  17.859354          10.859354       7
#
#    digit span  vocabulary
# 0           8           7
# 1           9          13
# 2           7          12
# 3          13          19
# 4           6           8

# %%
y = data["pred_age"]
x = data["vocabulary"]
#column = data.columns[0:8]
#column

# %%
a = sns.regplot(x, y,scatter_kws={'s':8,"alpha":0.9},ax = ax[i])
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
plt.figure(figsize=(3,2))
a = sns.regplot(x, y,scatter_kws={'s':8,"alpha":0.9})
a.spines['top'].set_visible(False)  #去掉上边框
a.spines['right'].set_visible(False) #去掉右边框
a.spines['bottom'].set_linewidth(1.5)#x轴变粗
a.spines['left'].set_linewidth(1.5)#y轴变粗
a.set_xlabel("vocabulary",labelpad = 3, fontdict={'weight': 'normal', 'size': 13}) #设置x轴名称
a.set_ylabel('pred_age') #设置y轴名称
a.set_xlim(0, 20)
#a.set_ylim(-2.5, 2.5)
a.tick_params(axis='both',pad=5,direction='in',width=1.5,labelsize=12)#坐标轴上刻度的粗细
plt.show()
#fig.tight_layout()
fig = a.get_figure()
fig.savefig("age_vocabualry.png",quality=95, dpi=800)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error two minor releases later
#   from ipykernel import kernelapp as app

# %%
fig, ax = plt.subplots(2, 4)
fig.set_size_inches(10,4)
ax = ax.flatten()

for i in range(8):
    x = data[column[i]]
    a = sns.regplot(x, y,scatter_kws={'s':8,"alpha":0.9},ax = ax[i])
    a.spines['top'].set_visible(False)  #去掉上边框
    a.spines['right'].set_visible(False) #去掉右边框
    a.spines['bottom'].set_linewidth(1.5)#x轴变粗
    a.spines['left'].set_linewidth(1.5)#y轴变粗
    a.set_xlabel(column[i],labelpad = 3, fontdict={'weight': 'normal', 'size': 13}) #设置x轴名称
    a.set_ylabel('') #设置y轴名称
    a.set_xlim(-3, 3)
    a.set_ylim(-2.5, 2.5)
    a.tick_params(axis='both',pad=5,direction='in',width=1.5,labelsize=12)#坐标轴上刻度的粗细
    #plt.xlabel(column[i],labelpad = 3, fontdict={'weight': 'normal', 'size': 13})
fig.tight_layout()
#fig.colorbar(ax=[ax[0], ax[1], ax[2], ax[3], ax[4]], fraction=0.01, pad=0.05)
# Out:
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.lmplot?

# %%
sns.regplot?

# %%
ax,xstick

# %%
plt.ylabel?
